# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 7043
# Columns : 21

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,5))
sns.countplot(data=df,x="Churn")
plt.title("Customer Churn Distribution")
plt.show()

# %%
churn_percent=df["Churn"].value_counts(normalize=True)*100
print(churn_percent)
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df,x="Contract",hue="Churn")
plt.title("Contract Type vs Churn")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df,x="Churn",y="MonthlyCharges")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=df,x="tenure",hue="Churn",multiple="stack")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.countplot(data=df,x="InternetService",hue="Churn")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.countplot(data=df,x="SeniorCitizen",hue="Churn")
plt.show()

# %%
print("""
Business Problem

Telecommunication companies lose significant revenue due to customer churn.

Retaining an existing customer is much cheaper than acquiring a new one.

The company wants to identify customers who are likely to leave so that proactive retention strategies can be implemented.
""")
# Out:
# Business Problem
#
# Telecommunication companies lose significant revenue due to customer churn.
#
# Retaining an existing customer is much cheaper than acquiring a new one.
#
# The company wants to identify customers who are likely to leave so that proactive retention strategies can be implemented.

# %%
objectives=[
"Reduce customer churn",
"Identify high-risk customers",
"Improve customer satisfaction",
"Increase customer retention",
"Optimize marketing campaigns"
]

for i,obj in enumerate(objectives,1):
    print(f"{i}. {obj}")
# Out:
# 1. Reduce customer churn
# 2. Identify high-risk customers
# 3. Improve customer satisfaction
# 4. Increase customer retention
# 5. Optimize marketing campaigns

# %%
stakeholders=[
"Marketing Team",
"Customer Support",
"Sales Team",
"Business Managers",
"Executive Leadership"
]

for s in stakeholders:
    print("-",s)
# Out:
# - Marketing Team
# - Customer Support
# - Sales Team
# - Business Managers
# - Executive Leadership

# %%
print("""
Expected Outcome

• Predict customers likely to churn

• Improve retention campaigns

• Increase company revenue

• Reduce customer acquisition costs
""")
# Out:
# Expected Outcome
#
# • Predict customers likely to churn
#
# • Improve retention campaigns
#
# • Increase company revenue
#
# • Reduce customer acquisition costs

# %%
print("""
Key Insights

1. Month-to-month contracts have the highest churn.

2. Customers with higher monthly charges churn more.

3. Customers with shorter tenure leave more often.

4. Fiber optic users exhibit relatively higher churn.

5. Senior citizens have a higher churn tendency.
""")
# Out:
# Key Insights
#
# 1. Month-to-month contracts have the highest churn.
#
# 2. Customers with higher monthly charges churn more.
#
# 3. Customers with shorter tenure leave more often.
#
# 4. Fiber optic users exhibit relatively higher churn.
#
# 5. Senior citizens have a higher churn tendency.

# %%
print("""
Conclusion

This project identifies the major business factors responsible for customer churn.

The insights obtained will help decision-makers implement targeted retention strategies and improve customer loyalty.
""")
# Out:
# Conclusion
#
# This project identifies the major business factors responsible for customer churn.
#
# The insights obtained will help decision-makers implement targeted retention strategies and improve customer loyalty.
